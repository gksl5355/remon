# %%
from app.ai_pipeline.graph import build_graph
from app.ai_pipeline.state import AppState

# 그래프 빌드
graph = build_graph()

# 테스트 입력 데이터
test_input = AppState(
    # AppState에 필요한 초기 데이터 입력
    # 예: regulation_text="테스트 규제", country_code="US" 등
)

# 실행
result = graph.invoke(test_input)
print("결과:", result)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from app.ai_pipeline.graph import build_graph
#       2 from app.ai_pipeline.state import AppState
#       4 # 그래프 빌드
#
# File ~/remon/app/ai_pipeline/graph.py:15
#      11 from app.ai_pipeline.state import AppState
#      13 # TODO: 각 노드 모듈 임포트
#      14 # 실제 프로젝트 구조에 맞게 경로 조정 필요
# ---> 15 from app.ai_pipeline.preprocess import preprocess_node
#      16 from app.ai_pipeline.nodes.map_products import map_products_node      # def map_products_node(state: AppState) -> dict
#      17 from app.ai_pipeline.nodes.generate_strategy import (                 # def generate_strategy_node(state: AppState) -> dict
#      18     generate_strategy_node,                                           # def validate_strategy_node(state: AppState) -> dict
#      19     validate_strategy_node,
#      20 )
#
# ...
